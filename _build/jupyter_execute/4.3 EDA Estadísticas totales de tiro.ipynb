# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from funciones_auxiliares import *
import warnings
import numpy as np
warnings.filterwarnings('ignore')

# %% [markdown]
# # 4.3 Análisis exploratorio de *estadísticas totales de tiro*

# %% [markdown]
# En el siguiente notebook, se pasa a realizar el análisis exploratorio de los datos procesados referentes a las *estadísticas totales de quintetos*. Este análisis exploratorio estará dividido en los siguientes apartados con el fin de poder comprender y conocer los datos que han sido descargados y transformados:
# * **1. Análisis de consistencia de los datos.** Se realizará el análisis de volumetrías referentes a los datos descargados con el fin de tener una imagen global de estos.
# * **2. Análisis univariante de los datos.** Se realizará una análisis de cada una de las variables para conocer la información que esta almacena y la distribución de esta dentro de la variable.
# * **3. Conclusiones.** Se cerrará el documento destacando los puntos más relevantes tras la realización del análisis.
#
# A través de estos puntos se espere conocer por completo la informaición que se tiene para el cumplimiento de los objetivos del Trabajo Fin de Máster.

# %% [markdown]
# ## 1. Análisis de consistencia de los datos

# %% [markdown]
# En el análisis de consistencia de los datos se buscará concocer la estructura de estos y la información que en su variables se almacena. Es por este motivo que se pasa a realiza la construcción de un dataframe con todos los registros de los quintetos en el que se almacenen estadísticas totales de quintetos:

# %%
# Ruta de estadísticas
ruta_estadisticas = 'E:/TFM/02. Datos/ACB/ESTADISTICAS'

# Se realiza la inicialización del tablon de estadísticas
df_estadisticas_totales = pd.DataFrame()

# Se extrae el listado de directorios de temporadas
l_dir_temporadas = ['2019','2020', '2021', '2022']

for temporada in l_dir_temporadas:
    # Se extrae el listado de directorios de equipos
    ruta_dir_temporada = ruta_estadisticas + '/' + temporada
    l_dir_equipos = os.listdir(ruta_dir_temporada)
    
    for equipo in l_dir_equipos:
        # Se inicializa la ruta de estadísticas de un equipo
        ruta_dir_estadisticas_equipo = ruta_dir_temporada + '/' + equipo
        
        # Se realiza la carga de ficheros de estadísticas de jugadores
        df_estadisticas_totales_equipo = pd.read_csv(ruta_dir_estadisticas_equipo + '/02_ESTADISTICAS_CARTA_TIRO_EQUIPO.csv', sep = ';')
        
        # Se incluye el fichero cargado en el dataframe de estadísticas totales
        df_estadisticas_totales = pd.concat([df_estadisticas_totales,df_estadisticas_totales_equipo])

# %% [markdown]
# Tras la construccion del fichero global con las estadísticas totales de los jugadores, se pasa a realizar la extracción de volumetrías del conjunto de datos:

# %%
print("#######################################")
print("# RESUMEN DEL TABLÓN DE ESTADISTICAS")
print("#######################################")
print("Nº de registros:",df_estadisticas_totales.shape[0])
print("Nº de columnas:",df_estadisticas_totales.shape[1])
print("Columnas:", (' | ').join(df_estadisticas_totales.columns))
print("Nº de elementos vacíos:",(df_estadisticas_totales=='').sum().sum())
print("Nº de elementos nulos:",df_estadisticas_totales[df_estadisticas_totales.columns].isna().sum().sum())
print("\n",df_estadisticas_totales.head().to_string(index=False, col_space=4))
# Out:
# #######################################
# # RESUMEN DEL TABLÓN DE ESTADISTICAS
# #######################################
# Nº de registros: 1242
# Nº de columnas: 25
# Columnas: D | NOMBRE | GRUPO 1_IN | GRUPO 1_OUT | GRUPO 10_IN | GRUPO 10_OUT | GRUPO 11_IN | GRUPO 11_OUT | GRUPO 2_IN | GRUPO 2_OUT | GRUPO 3_IN | GRUPO 3_OUT | GRUPO 4_IN | GRUPO 4_OUT | GRUPO 5_IN | GRUPO 5_OUT | GRUPO 6_IN | GRUPO 6_OUT | GRUPO 7_IN | GRUPO 7_OUT | GRUPO 8_IN | GRUPO 8_OUT | GRUPO 9_IN | GRUPO 9_OUT | Fuera de límites_OUT
# Nº de elementos vacíos: 0
# Nº de elementos nulos: 6988
#
#     D    NOMBRE  GRUPO 1_IN  GRUPO 1_OUT  GRUPO 10_IN  GRUPO 10_OUT  GRUPO 11_IN  GRUPO 11_OUT  GRUPO 2_IN  GRUPO 2_OUT  GRUPO 3_IN  GRUPO 3_OUT  GRUPO 4_IN  GRUPO 4_OUT  GRUPO 5_IN  GRUPO 5_OUT  GRUPO 6_IN  GRUPO 6_OUT  GRUPO 7_IN  GRUPO 7_OUT  GRUPO 8_IN  GRUPO 8_OUT  GRUPO 9_IN  GRUPO 9_OUT  Fuera de límites_OUT
#    0 B. Davies       114.0         96.0          NaN           NaN          NaN           NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN                   NaN
#    3 K. Pangos         2.0          2.0          NaN           NaN          NaN           NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN                   NaN
#    5  P. Ribas        18.0         23.0          NaN           NaN          NaN           NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN                   NaN
#    8  A. Hanga        70.0         84.0          NaN           NaN          NaN           NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN                   NaN
#   10  R. Smits        19.0         27.0          NaN           NaN          NaN           NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN         NaN          NaN                   NaN

# %% [markdown]
# Como se puede observar, el número de registros de estadísticas totales de jugadores es de 1.242 que dan información a 25 variables diferentes como ya se había observado durante el procesamiento de este tipo de estadística. Con respecto a la estructura de los datos que esta variable almacena, de manera genérica, podemos observar todas las variables estadísticas son de tipo numérico y que existen 6.988 elementos nulos que pertenecen a los registros de la temporada *2019-2020*.

# %% [markdown]
# ## 2. Análisis univariante de los datos.

# %% [markdown]
# Tras la inspección de manera general todos los registros en los que se almacena información referente a las estadísticas totales, se pasa a realizar el análisis univariante de cada una de ellas para conocer su estructura y el tipo de información que en estas variables se almacena:

# %% [markdown]
# ### 2.1 Variable *GRUPO 1_IN*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 1_IN'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 142
# Media de la variable: 38.34460547504026
# Mediana de la variable: 29.0
# Desviación típica de la variable: 35.37063465668472
# Valor mínimo: 0.0
# Valor máximo: 210.0
# Sumatorio de tiros realizados: 47624.0

# %% [markdown]
# ### 2.2 Variable *GRUPO 1_OUT*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 1_OUT'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 134
# Media de la variable: 33.72302737520129
# Mediana de la variable: 26.0
# Desviación típica de la variable: 31.70107054698937
# Valor mínimo: 0.0
# Valor máximo: 210.0
# Sumatorio de tiros realizados: 41884.0

# %% [markdown]
# ### 2.3 Variable *GRUPO 2_IN*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 2_IN'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 15
# Media de la variable: 1.8598524762908324
# Mediana de la variable: 1.0
# Desviación típica de la variable: 2.4296777015662205
# Valor mínimo: 0.0
# Valor máximo: 19.0
# Sumatorio de tiros realizados: 1765.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.4 Variable *GRUPO 1_OUT*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 2_OUT'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 20
# Media de la variable: 3.095890410958904
# Mediana de la variable: 2.0
# Desviación típica de la variable: 3.2882404546437316
# Valor mínimo: 0.0
# Valor máximo: 20.0
# Sumatorio de tiros realizados: 2938.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.5 Variable *GRUPO 3_IN*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 3_IN'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 13
# Media de la variable: 1.7049525816649105
# Mediana de la variable: 1.0
# Desviación típica de la variable: 2.133564083693283
# Valor mínimo: 0.0
# Valor máximo: 14.0
# Sumatorio de tiros realizados: 1618.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.6 Variable *GRUPO 3_OUT*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 3_OUT'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 18
# Media de la variable: 2.822971548998946
# Mediana de la variable: 2.0
# Desviación típica de la variable: 2.9763943334330945
# Valor mínimo: 0.0
# Valor máximo: 18.0
# Sumatorio de tiros realizados: 2679.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.7 Variable *GRUPO 4_IN*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 4_IN'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 15
# Media de la variable: 1.0769230769230769
# Mediana de la variable: 0.0
# Desviación típica de la variable: 1.928408707408974
# Valor mínimo: 0.0
# Valor máximo: 22.0
# Sumatorio de tiros realizados: 1022.0
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.8 Variable *GRUPO 4_OUT*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 4_OUT'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 18
# Media de la variable: 1.898840885142255
# Mediana de la variable: 1.0
# Desviación típica de la variable: 2.6422182386086805
# Valor mínimo: 0.0
# Valor máximo: 18.0
# Sumatorio de tiros realizados: 1802.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.9 Variable *GRUPO 5_IN*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 5_IN'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 18
# Media de la variable: 1.5374077976817704
# Mediana de la variable: 0.0
# Desviación típica de la variable: 2.6144522913887007
# Valor mínimo: 0.0
# Valor máximo: 23.0
# Sumatorio de tiros realizados: 1459.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.10 Variable *GRUPO 5_OUT*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 5_OUT'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 23
# Media de la variable: 2.243414120126449
# Mediana de la variable: 1.0
# Desviación típica de la variable: 3.359094233552364
# Valor mínimo: 0.0
# Valor máximo: 31.0
# Sumatorio de tiros realizados: 2129.0
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.11 Variable *GRUPO 6_IN*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 6_IN'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 17
# Media de la variable: 1.0052687038988408
# Mediana de la variable: 0.0
# Desviación típica de la variable: 2.0160154272818644
# Valor mínimo: 0.0
# Valor máximo: 25.0
# Sumatorio de tiros realizados: 954.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.12 Variable *GRUPO 6_OUT*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 6_OUT'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 18
# Media de la variable: 1.719704952581665
# Mediana de la variable: 1.0
# Desviación típica de la variable: 2.4954476521428206
# Valor mínimo: 0.0
# Valor máximo: 23.0
# Sumatorio de tiros realizados: 1632.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.13 Variable *GRUPO 7_IN*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 7_IN'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 8
# Media de la variable: 0.5795574288724974
# Mediana de la variable: 0.0
# Desviación típica de la variable: 1.0287242796719793
# Valor mínimo: 0.0
# Valor máximo: 7.0
# Sumatorio de tiros realizados: 550.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.14 Variable *GRUPO 7_OUT*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 7_OUT'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 9
# Media de la variable: 0.9209694415173867
# Mediana de la variable: 0.0
# Desviación típica de la variable: 1.3165101819552252
# Valor mínimo: 0.0
# Valor máximo: 9.0
# Sumatorio de tiros realizados: 874.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.15 Variable *GRUPO 8_IN*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 8_IN'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 37
# Media de la variable: 5.798735511064278
# Mediana de la variable: 3.0
# Desviación típica de la variable: 6.919561832379534
# Valor mínimo: 0.0
# Valor máximo: 44.0
# Sumatorio de tiros realizados: 5503.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.16 Variable *GRUPO 8_OUT*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 8_OUT'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 52
# Media de la variable: 10.461538461538462
# Mediana de la variable: 7.0
# Desviación típica de la variable: 11.234827844803391
# Valor mínimo: 0.0
# Valor máximo: 72.0
# Sumatorio de tiros realizados: 9928.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.17 Variable *GRUPO 9_IN*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 9_IN'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 27
# Media de la variable: 3.613277133825079
# Mediana de la variable: 1.0
# Desviación típica de la variable: 4.860834684200275
# Valor mínimo: 0.0
# Valor máximo: 27.0
# Sumatorio de tiros realizados: 3429.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.18 Variable *GRUPO 9_OUT*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 9_OUT'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 41
# Media de la variable: 6.931506849315069
# Mediana de la variable: 4.0
# Desviación típica de la variable: 8.214075854062505
# Valor mínimo: 0.0
# Valor máximo: 46.0
# Sumatorio de tiros realizados: 6578.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.19 Variable *GRUPO 10_IN*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 10_IN'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 38
# Media de la variable: 5.8619599578503685
# Mediana de la variable: 3.0
# Desviación típica de la variable: 7.040038954095948
# Valor mínimo: 0.0
# Valor máximo: 42.0
# Sumatorio de tiros realizados: 5563.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.20 Variable *GRUPO 10_OUT*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 10_OUT'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 55
# Media de la variable: 11.066385669125395
# Mediana de la variable: 7.0
# Desviación típica de la variable: 11.807207343659467
# Valor mínimo: 0.0
# Valor máximo: 60.0
# Sumatorio de tiros realizados: 10502.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.21 Variable *GRUPO 11_IN*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 11_IN'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 9
# Media de la variable: 0.5742887249736565
# Mediana de la variable: 0.0
# Desviación típica de la variable: 1.0504231842057852
# Valor mínimo: 0.0
# Valor máximo: 8.0
# Sumatorio de tiros realizados: 545.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.22 Variable *GRUPO 11_OUT*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'GRUPO 11_OUT'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 8
# Media de la variable: 0.8240252897787145
# Mediana de la variable: 0.0
# Desviación típica de la variable: 1.2973570274769117
# Valor mínimo: 0.0
# Valor máximo: 7.0
# Sumatorio de tiros realizados: 782.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ### 2.23 Variable *Fuera de límites_OUT*

# %%
print("#############################")
print("INFORMACIÖN DE LA VARIABLE")
print("#############################")
variable = 'Fuera de límites_OUT'
print("Tipo de variable:", df_estadisticas_totales[variable].dtype)
print("Nº de valores únicos:", df_estadisticas_totales[variable].nunique())
print("Media de la variable:", df_estadisticas_totales[variable].mean())
print("Mediana de la variable:", df_estadisticas_totales[variable].median())
print("Desviación típica de la variable:", df_estadisticas_totales[variable].std())
print("Valor mínimo:", df_estadisticas_totales[variable].min())
print("Valor máximo:", df_estadisticas_totales[variable].max())
print("Sumatorio de tiros realizados:",df_estadisticas_totales[variable].sum())

# Obtención de visualizaciónes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
obtener_distribucion_variable(df_estadisticas_totales, variable, ax1)
obtener_boxplot_variable(df_estadisticas_totales, variable, ax2)
plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# #############################
# INFORMACIÖN DE LA VARIABLE
# #############################
# Tipo de variable: float64
# Nº de valores únicos: 2
# Media de la variable: 0.07017543859649122
# Mediana de la variable: 0.0
# Desviación típica de la variable: 0.2565702389853346
# Valor mínimo: 0.0
# Valor máximo: 1.0
# Sumatorio de tiros realizados: 8.0
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# ## 3. Conclusiones

# %% [markdown]
# Tras el análisis de todas las variables que constiyen las *estadísticas totales individuales* se pasa a comentar las siguientes conclusiones sobre el conjunto de datos:
# * **Estructura de la información.** Como ha sido observado, todas las variables que conforman el conjunto de datos se encuentra en formato numérico (ya sea en formato int64 o float). Además, ha sido detectado que en la temporada *2019-2020* únicamente existen tiros realizados dentro del Grupo 1 lo que hace muy dificil la utilización de estos datos para esta temporada.
# * **Distribución y variabilidad en las variables.** De manera general, se ha observado que en todas las variables existe un alto grado de diversidad de valores y un alto grado de variabilidad de valores. Además, también se puede observar de manera generalizada que la media supera a la mediana en las variables lo que indica una tendencia en la variables a valores más altos que dependiendo del uso que se den pueden considerarse como valores atípicos.
# * **Centralización de tiros.** Como puede observarse en las distintas distribuciones, la mayoría de tiros han sido realizados desde el *Grupo 1* y desde donde menos los *Grupos 7 y 11**, se pone sobre aviso que si se utilizan estas variables con los valores absolutos pueden que no sean lo más correctas a la hora de crear agrupaciones.
# * **Fuera de límites.** Se localizan en la temporada +2019-2020* diversos tiros que no han podido ser localizados dentro de ningún area.
#
# Estos puntos son los más relevantes tras el análisis del conjunto de datos y se tendrán en cuenta para el uso de los datos en los futuros análisis dentro del Trabajo Fin de Máster.
